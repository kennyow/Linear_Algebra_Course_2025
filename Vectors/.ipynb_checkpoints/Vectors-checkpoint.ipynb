# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# #### Algebraic and Geometric Interpretations

# %%
# 2-dimensional vector
v2 = [ 3, -2]

# 3- dimensional vector
v3 = [4, -3, 2]

# row to column ( or vice-versa): Transpose
v3t = np.transpose(v3)

# %%
#plot the 2d vectors
plt.plot([0, v2[0]], [0, v2[1]])
plt.axis('equal')
plt.plot([-4, 4], [0,0], 'k--') #Eixos pontilhados
plt.plot([0,0],[-4, 4], 'k--')
plt.grid() #tabulação
plt.axis((-4, 4, -4, 4))
plt.show()

# %%
# plot the 3d vectos
fig = plt.figure(figsize=plt.figaspect(1))
ax = fig.gca(projection='3d') # Projeta o espaço tabular em 3d
ax.plot([0, v3[0]], [0, v3[1]], [0, v3[2]], linewidth=3) #projetando a reta

# make a plot look nicer
ax.plot([0,0], [0,0], [-4,4], 'k--') #projetando o pontilhado no eixo z
ax.plot([0,0], [-4,4], [0,0],  'k--') #projetando o pontilhado no eixo x
ax.plot([-4,4], [0,0],  [0,0],  'k--') #projetando o pontilhado no eixo y
# Out:
# C:\Users\kenny\AppData\Local\Temp\ipykernel_11952\3122715272.py:3: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d') # Projeta o espaço tabular em 3d

# %% [markdown]
# ### VectorAdditionSubtraction

# %%
# two vectors in R2
v1 = np.array([3 , -1])
v2 = np.array([2, 4])

v3 = v1 + v2

v3
# Out:
# array([5, 3])

# %%
# plotting the vectors

plt.plot([0, v1[0]], [0, v1[1]], 'b', label = 'v1') #linha v1 b - blue
plt.plot([0, v2[0]] + v1[0], [0, v2[1]] + v1[1], 'r', label = 'v2') #linha v2 soma
plt.plot([0, v3[0]], [0, v3[1]], 'k', label = 'v1+v2') #vetor resultante

plt.legend() # legenda no canto superior
plt.axis('square') # redimensiona a imagem para um quadrado
plt.axis((-6, 6, -6, 6)) # redimensiona o quadrado em 6 por 6
plt.grid() #tabulação
plt.show()

# %% [markdown]
# ### VectorScalarMultiplication

# %%
# Vector and scalar
v1 = np.array([3, -1])
l = -.3
v1m = v1*l # Scalar modulated

#plot
plt.plot([0, v1[0]], [0, v1[1]], 'b', label='v_1') #linha v1 azul (b)
plt.plot([0, v1m[0]], [0, v1m[1]], 'r', label='\lambda v_1') #vetor modulado vermelho

plt.axis('square') # redimensiona a imagem para quadrada
axlim = max([abs(max(v1)), abs(max(v1m))])*1.5 
plt.axis((-axlim, axlim, -axlim, axlim))
plt.grid() #tabulação
plt.show()

# %% [markdown]
# #### VectorMultiplication: The dot product

# %%
# Various ways of doing vector multiplication

v1 = np.array([1, 2, 3, 4, 5])
v2 = np.array([0, -4, -3, 6, 5 ])

#method 1
dp1 = sum(np.multiply(v1, v2))
print(f"Método 1: {dp1}")

#method 2
dp2 = np.dot(v1, v2)
print(f"Método 2: {dp2}")

#method 3
dp3 = np.matmul(v1, v2)
print(f"Método 3: {dp3}")

#method 4
dp4 = 0

#Loop over elements 
for i in range (0, len(v1)):
    
    #mltiply corresponding element and sum
    dp4 = dp4 + v1[i]*v2[i]
    
print(f"Método 4: {dp4}")
# Out:
# Método 1: 32
# Método 2: 32
# Método 3: 32
# Método 4: 32

# %% [markdown]
# #### Dot Product Properties: Associative and Distributive

# %%
## Distributive Property

#Create random vectors

n = 10
a = np.random.randn(n)
print(f"ponto a: {a}")
print()
b = np.random.randn(n)
print(f"ponto b: {b}")
print()
c = np.random.randn(n)
print(f"ponto c: {c}")
print()

# the two results
res1 = np.dot(a, (b+c))
res2 = np.dot(a,b) + np.dot(a,c)

#compare them
print([res1, res2])
# Out:
# ponto a: [ 0.71040283  0.48312016  0.1156242  -0.97980139 -0.32555918  0.39591758
#   1.81437109 -1.87160194 -1.05612577  0.13342435]
#
# ponto b: [-0.67212765  0.99626618 -0.55361331 -0.31680665  1.00522663 -0.22212528
#  -1.6709532  -0.57289933 -0.7342477   1.12198091]
#
# ponto c: [-0.38046147 -0.88884467 -1.17702171 -0.28355688 -0.06761921  0.45222748
#   0.1402859   0.24838474  0.70654069  0.64395807]
#
# [-2.426831267048055, -2.426831267048055]

# %%
matriz1 = np.random.rand(4, 6)  # Valores aleatórios entre 0 e 1
print(matriz1)
print()

matriz2 = np.random.rand(4, 6)  # Valores aleatórios entre 0 e 1
print(matriz2)
print()

dps = np.zeros(6)
print(dps)

for i in range(6):
    dps[i] = np.dot(matriz1[:,i], matriz2[:,i])
    
print()
print(dps)
# Out:
# [[0.0272698  0.69850281 0.50873559 0.1144676  0.06164359 0.31172849]
#  [0.208664   0.13296323 0.53159822 0.69652153 0.31369553 0.39364332]
#  [0.50010576 0.6679392  0.59842286 0.62983414 0.50466563 0.07984972]
#  [0.67154029 0.00785171 0.40030815 0.42913092 0.24082545 0.50212588]]
#
# [[0.40953545 0.78154507 0.4741769  0.65066848 0.32918344 0.64897255]
#  [0.83546301 0.86597981 0.85206688 0.18482519 0.30367173 0.64292467]
#  [0.34022412 0.12735187 0.64062641 0.15458881 0.89759199 0.41326036]
#  [0.59576056 0.34179584 0.85044833 0.25093444 0.83145205 0.17909105]]
#
# [0. 0. 0. 0. 0. 0.]
#
# [0.75572427 0.74880188 1.41799478 0.40826421 0.76877115 0.57831121]

# %% [markdown]
# #### Is dot product commutative?

# %%
v1 = np.random.randn(100)
v2 = np.random.randn(100)

res1 = np.dot(v1, v2)
res2 = np.dot(v2, v1)
print(res1, res2, res1-res2)

if res1 == res2:
    print("São iguais")
    
#Test with 2-element random vectors
v = [2,4]
w = [3, 5]
print(np.dot(v,w), np.dot(w,v))
# Out:
# -2.841851091248241 -2.841851091248241 0.0
# São iguais
# 26 26

# %% [markdown]
# #### Vector Length
#
# $$
# \|v\| = \sqrt{v^T v}
# $$

# %%
# a vector
v1 = np.array([1, 2, 3, 4, 5, 6])

# #methods 1-4, just like with the regular dot product, e.g.:
vl1 = np.sqrt(sum(np.multiply(v1,v1)))

#method 2
vl2 = np.sqrt(np.dot(v1, v1))
print(f"Método 2: {vl2}")

#method 3
vl3 = np.sqrt(np.matmul(v1, v1))
print(f"Método 3: {vl3}")

#method 4 using for loop

#method 5: take the norm
vl5 = np.linalg.norm(v1)
print(f"Método 5: {vl5}")
# Out:
# Método 2: 9.539392014169456
# Método 3: 9.539392014169456
# Método 5: 9.539392014169456

# %% [markdown]
# ##### The dot product from a geometric perspective
#
# $$ \alpha = |a||b|cos(\theta_{ab} = a^Tb)$$

# %% [markdown]
# | Thetha < 90° | Theta > 90° | Theta = 90° | Theta = 0° |
# |--------------|-------------|-------------|------------|
# | Cos(theta) > 0 | Cos(theta) < 0 | Cos(theta) = 0 | Cos(theta) = 1 |
# | alfa > 0       | alfa < 0       | alfa = 0       | alfa = (\|a\|\|b\|) |

# %%
# two vectors
v1 = np.array([2, 4, -3])
v2 = np.array([0, -3, -3])

# Compute the angle (radians) between two vectors
ang = np.arccos(np.dot(v1, v2)/(np.linalg.norm(v1)*np.linalg.norm(v2)))

#draw them

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot([0, v1[0]], [0, v1[1]], [0,v1[2]], 'b')
ax.plot([0, v2[0]], [0, v2[1]], [0,v2[2]], 'r')


plt.axis((-6, 6, -6, 6))
plt.title(f'Angle between vectors: {ang} rad.')
plt.show()
# Out:
# C:\Users\kenny\AppData\Local\Temp\ipykernel_11952\102806791.py:11: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
# equivalence of algebraic and geometric dot product formulas
v1 = np.array([2, 4, -3])
v2 = np.array([0, -3, -3])

# algebraic
dp_a = np.dot(v1, v2)

#geometric
dp_g = np.linalg.norm(v1)*np.linalg.norm(v2)*np.cos(ang)

print(dp_a)
print(dp_g)
# Out:
# -3
# -3.0000000000000013

# %% [markdown]
# #Cauchy-Schwarz Inequality
# $$|a^Tb| \leq ||a||*||b||$$
# #Prove
# $$||a||*||b||*|cos(\Theta_{ab})| \leq ||a||*||b|| $$
# $$|cos(\Theta_{ab})| \leq 1 $$
# $$ 0\leq |cos(\Theta_{ab})| \leq 1 $$

# %%
#create three vectors, one of which is dependent on another

a = np.random.randn(5)
b = np.random.randn(5)
c = np.random.randn(1) * a

#compute their dot products
aTb = np.dot(a,b)
aTc = np.dot(a,c)

#demonstrate the (in)equalities. Multiplying for the norm
print("The left is always less than or equal to the right")
print(f'{np.abs(aTb):.4f}, {np.linalg.norm(a)*np.linalg.norm(b):.4f}') #np.abs = absolute value
print("The left is always equal to the right")
print(f'{np.abs(aTc):.4f}, {np.linalg.norm(a)*np.linalg.norm(c):.4f}')
# Out:
# The left is always less than or equal to the right
# 0.6665, 1.5504
# The left is always equal to the right
# 0.7761, 0.7761

# %%
#challenge

#Generate two vectors
a = np.array([-3,4,5])
b = np.array([3,6,-3])

#Generate two scalars
s1 = 2
s2 = 3

#compute dot product between the vectors
product = np.dot(a,b)

#compute dot product between scaled vectors
product_vectors = np.dot(s1*a, s2*b)
print(f'Original dot product: {product}')
print(f'Scaled dot product: {product_vectors}')
# Out:
# Original dot product: 0
# Scaled dot product: 0

# %% [markdown]
# ## Vector Hadamard Multiplication

# %%
W1 = [1, 3, 5]
W2 = [3,4,2]

W3 = np.multiply(W1,W2)
W3
# Out:
# array([ 3, 12, 10])

# %% [markdown]
# ### Dot Product and Outer Product

# %% [markdown]
# $$\text{Dot Product: } V_{N \times 1}^T W_{N \times 1} = 1 \times 1$$
#
# $$\text{Outer Product: } V_{N \times 1} W_{M \times 1}^T = N \times M$$

# %%
#Computing the outer product

v1 = np.array([1, 2, 3])
v2 = np.array([-1, 0, 1])

#Outer product

op1 = np.outer(v1, v2)

#Terrible programing, but helps conceptually:
op2 = np.zeros((len(v1), len(v2))) 
for i in range(0, len(v1)):
    for j in range(0, len(v2)):
        op2[i,j] = v1[i]*v2[j]
        
print(op1)
print('')
print(op2)
# Out:
# [[-1  0  1]
#  [-2  0  2]
#  [-3  0  3]]
#
# [[-1.  0.  1.]
#  [-2.  0.  2.]
#  [-3.  0.  3.]]

# %% [markdown]
# ## Vector Cross Product

# %%
#  Create vectors
v1 = [-3, 2 , 5]
v2 = [4, -3, 0]

#Python's cross-product-function
v3a = np.cross(v1, v2)

#"Manual" method
v3b = [
    [v1[1]*v2[2] - v1[2]*v2[1]],
    [v1[2]*v2[0] - v1[0]*v2[2]],
    [v1[0]*v2[1] - v1[1]*v2[0]]
]
print(f'V3a: {v3a}\nV3b: {v3b}')

fig = plt.figure()
ax = fig.gca(projection='3d')

#draw plane defined by span of v1 and v2
xx, yy = np.meshgrid(np.linspace(-10, 10, 10), np.linspace(-10, 10, 10))
z1 = (-v3a[0]*xx - v3a[1]*yy)/v3a[2]
ax.plot_surface(xx,yy,z1)

# Plot the two vectors
ax.plot([0, v1[0]], [0, v1[1]], [0, v1[2]], 'k')
ax.plot([0, v2[0]], [0, v2[1]], [0, v2[2]], 'k')
ax.plot([0, v3a[0]], [0, v3a[1]], [0, v3a[2]], 'r')

ax.view_init(azim=150, elev=45)
plt.show()
# Out:
# V3a: [15 20  1]
# V3b: [[15], [20], [1]]
# C:\Users\kenny\AppData\Local\Temp\ipykernel_11952\3488350899.py:17: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %% [markdown]
# ## Complex Numbers - Hermitian transpose

# %%
#Hermitian transpose:  conjugado dos números complexos. Em caso de transposição, apenas os números complexos são afetados, sendo trocados pelos seus respectivos conjugados

#create a complex number
z = np.complex(3,4)
print(z)
#magnitude
print(np.linalg.norm(z))

#by transpose?
print(np.transpose(z)*z)

#by Hermitian transpose
print(np.transpose(z.conjugate())*z)

#create a complex vector
v = np.array([3, 4j, 5+2j, np.complex(2,-5)])
print(v.T)
print(np.transpose(v))
print(np.transpose(v.conjugate())) #o conjugado invertendo os sinais apenas nos números complexos
# Out:
# (3+4j)
# 5.0
# (-7+24j)
# (25+0j)
# [3.+0.j 0.+4.j 5.+2.j 2.-5.j]
# [3.+0.j 0.+4.j 5.+2.j 2.-5.j]
# [3.-0.j 0.-4.j 5.-2.j 2.+5.j]
# C:\Users\kenny\AppData\Local\Temp\ipykernel_11952\335095238.py:4: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   z = np.complex(3,4)
# C:\Users\kenny\AppData\Local\Temp\ipykernel_11952\335095238.py:16: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   v = np.array([3, 4j, 5+2j, np.complex(2,-5)])

# %% [markdown]
# ## Unit Vector

# %%
#vector
v1 = np.array([-.3, .6])/10

#mi (mu)
mu = 1/np.linalg.norm(v1)

v1n = v1*mu

#Plot

plt.plot([0, v1n[0]], [0, v1n[1]], 'r',  label = 'v1-norm', linewidth=5)
plt.plot([0,v1[0]], [0, v1[1]], 'b', label='v1')

#axis square
plt.axis('square')
plt.axis((-6,6,-6,6))
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Challenge

# %%
# create two random vectors
n = 4
v1 = np.round(20*np.random.randn(n))
v2 = np.round(20*np.random.randn(n))
print(f'Vector1: {v1}\nVector 2:{v2}')

#compute the lengths of the individuals vectors, and magnitude their dot product
v1m = np.sqrt(np.dot(v1,v1))
print(f'Length of Vector 1: {v1m}')
v2m = np.sqrt(np.dot(v2,v2))
print(f'Length of Vector 2: {v2m}')
# dot product magnitude
dpm = np.abs(np.dot(v1,v2))
print(f'Dot Product Magnitude: {dpm}')
print(' ') #Always larger than the length of the dot products alone
#normalize the vectors
v1u = v1/v1m
v2u = v2/v2m
print(f'v1u: {v1u}, v2u: { v2u}')
print(' ')
#compute the magnitude od that dot product
dpm = np.abs(np.dot(v1u, v2u))
print(f'Magnitude of dot product: {dpm:.3f}')
# Out:
# Vector1: [-3. -6. -0. 28.]
# Vector 2:[-28. -16. -10.  10.]
# Length of Vector 1: 28.792360097775937
# Length of Vector 2: 35.21363372331802
# Dot Product Magnitude: 460.0
#
# v1u: [-0.10419431 -0.20838861 -0.          0.9724802 ], v2u: [-0.79514657 -0.45436947 -0.28398092  0.28398092]
#
# Magnitude of dot product: 0.454

# %% [markdown]
# ## Dimensions
